# %%
Data Types:

1)What are the primitive data types in most programming languages?
2)Explain the difference between integer and floating-point data types.
3)What is the purpose of a boolean data type? Give an example.
4)Describe the concept of type casting or type conversion in programming.
5)How does a string data type differ from a character data type?
6)What are composite data types? Provide examples.
7)Explain the significance of the null or undefined value in programming.
8)How do you declare and use constants in your programming language? 




Operators:

1)Differentiate between unary, binary, and ternary operators with examples.
2)What is the difference between the "==" and "===" operators in JavaScript?
3)Explain the concept of short-circuiting in logical operators.
4)How does the modulo (%) operator work, and in what scenarios is it useful?
5)Describe the difference between the pre-increment (++x) and post-increment (x++) operators.
6)Discuss the purpose of the bitwise operators (&, |, ^, ~) and give an example.
7)What is operator precedence, and how does it affect the outcome of expressions?
8)How do you overload operators in languages that support operator overloading, like C++?



Conditional Statements:

1)What is the difference between an if statement and a switch statement?
2)Explain the concept of a ternary conditional operator (?:) and its usage.
3)How can you avoid common mistakes when working with multiple nested if-else statements?
4)Discuss the importance of short-circuit evaluation in conditional statements.
5)What is the "else if" statement, and when should you use it instead of just "if" and "else"?
6)How can you achieve multiple conditions using the logical AND (&&) and logical OR (||) operators?
7)Provide an example of using a "guard clause" to improve the readability of your code.



Looping Statements:

1)Compare and contrast the "for" loop, "while" loop, and "do-while" loop.
2)How can you prevent infinite loops? Provide strategies or techniques.
3)Explain the purpose of the "break" and "continue" statements within loops.
4)When might you use a "for-each" loop (or equivalent) instead of a traditional "for" loop?
5)Discuss the concept of loop unrolling and its potential performance benefits.



Functions:

1)What is the difference between a function declaration and a function expression?
2)Explain the concept of function scope versus global scope.
3)How do you pass arguments to a function, and what is the difference between call by value and call by reference?
4)Discuss the importance of return values in functions and how to handle them.
5)What is function overloading, and do all programming languages support it?
6)How can you create an anonymous function (lambda function), and what are its use cases?
7)Explain the difference between recursion and iteration. Provide an example of a recursive function.
